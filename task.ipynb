# %%
import pandas as pd
import numpy as np
import json
import re

# %%
df = pd.read_csv('Ashutosh.csv')

# %%
df.head()
# Out:
#                         Title  \
# 0                      Django
# 1  Coding: Intermediate level
# 2                      Docker
# 3                     ASP.NET
# 4          Creating REST APIs
#
#                                        JSON Response
# 0  {\n    "id": 1250569,\n    "name": "Django",\n...
# 1  {\n    "id": 1471468,\n    "name": "Coding: In...
# 2  {\n    "id": 170977,\n    "name": "Docker",\n ...
# 3  {\n    "id": 895134,\n    "name": "ASP.NET (in...
# 4  {\n    "id": 1950355,\n    "name": "Creating R...

# %%
df.shape
# Out:
# (223, 2)

# %%
df.isnull().sum()
# Out:
# Title            4
# JSON Response    5
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Title', 'JSON Response'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Title            0
# JSON Response    0
# dtype: int64

# %%
df.head()
# Out:
#                         Title  \
# 0                      Django
# 1  Coding: Intermediate level
# 2                      Docker
# 3                     ASP.NET
# 4          Creating REST APIs
#
#                                        JSON Response
# 0  {\n    "id": 1250569,\n    "name": "Django",\n...
# 1  {\n    "id": 1471468,\n    "name": "Coding: In...
# 2  {\n    "id": 170977,\n    "name": "Docker",\n ...
# 3  {\n    "id": 895134,\n    "name": "ASP.NET (in...
# 4  {\n    "id": 1950355,\n    "name": "Creating R...

# %%
df.rename(columns={df.columns[0]: 'Title'}, inplace=True)
if 'JSON response' not in df.columns:
    df.rename(columns={df.columns[1]: 'json_response'}, inplace=True)
df.dropna(axis=1, how='all', inplace=True)
print(df.head())
# Out:
#                         Title  \
# 0                      Django
# 1  Coding: Intermediate level
# 2                      Docker
# 3                     ASP.NET
# 4          Creating REST APIs
#
#                                        json_response
# 0  {\n    "id": 1250569,\n    "name": "Django",\n...
# 1  {\n    "id": 1471468,\n    "name": "Coding: In...
# 2  {\n    "id": 170977,\n    "name": "Docker",\n ...
# 3  {\n    "id": 895134,\n    "name": "ASP.NET (in...
# 4  {\n    "id": 1950355,\n    "name": "Creating R...

# %%
def is_valid_json(json_str):
    try:
        json.loads(json_str)
        return True
    except (json.JSONDecodeError, TypeError):
        return False

df = df[df['json_response'].apply(is_valid_json)].reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          217 non-null    object
#  1   json_response  217 non-null    object
# dtypes: object(2)
# memory usage: 3.5+ KB

# %%
df.head()
# Out:
#                         Title  \
# 0                      Django
# 1  Coding: Intermediate level
# 2                      Docker
# 3                     ASP.NET
# 4          Creating REST APIs
#
#                                        json_response
# 0  {\n    "id": 1250569,\n    "name": "Django",\n...
# 1  {\n    "id": 1471468,\n    "name": "Coding: In...
# 2  {\n    "id": 170977,\n    "name": "Docker",\n ...
# 3  {\n    "id": 895134,\n    "name": "ASP.NET (in...
# 4  {\n    "id": 1950355,\n    "name": "Creating R...

# %%
def extract_type_name(json_str):
    try:
        data = json.loads(json_str)
        type_list = data.get("type", [])
        if isinstance(type_list, list) and len(type_list) > 0:
            return type_list[0].get("name", None)
        return None
    except (json.JSONDecodeError, TypeError, AttributeError):
        return None
df["type"] = df["json_response"].apply(extract_type_name)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          217 non-null    object
#  1   json_response  217 non-null    object
#  2   type           217 non-null    object
# dtypes: object(3)
# memory usage: 5.2+ KB

# %%
df.head()
# Out:
#                         Title  \
# 0                      Django
# 1  Coding: Intermediate level
# 2                      Docker
# 3                     ASP.NET
# 4          Creating REST APIs
#
#                                        json_response                type
# 0  {\n    "id": 1250569,\n    "name": "Django",\n...  Programming skills
# 1  {\n    "id": 1471468,\n    "name": "Coding: In...  Programming skills
# 2  {\n    "id": 170977,\n    "name": "Docker",\n ...     Software skills
# 3  {\n    "id": 895134,\n    "name": "ASP.NET (in...  Programming skills
# 4  {\n    "id": 1950355,\n    "name": "Creating R...  Programming skills

# %%
def extract_questions(json_str):
    try:
        data = json.loads(json_str)  # Convert string to dictionary
        questions_list = data.get("preview_questions", [])  # Get "preview_questions" list
        return questions_list if isinstance(questions_list, list) else []  # Ensure it's a list
    except (json.JSONDecodeError, TypeError, AttributeError):
        return []

df["questions"] = df["json_response"].apply(extract_questions)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          217 non-null    object
#  1   json_response  217 non-null    object
#  2   type           217 non-null    object
#  3   questions      217 non-null    object
# dtypes: object(4)
# memory usage: 6.9+ KB

# %%
df["questions"].head()
# Out:
# 0    [{'id': 1095950, 'text': '<p>You are working o...
# 1    [{'id': 1278402, 'text': '<p><span style="back...
# 2    [{'id': 155197, 'text': '<p>Given the Dockerfi...
# 3    [{'id': 615710, 'text': '<p>Which code snippet...
# 4    [{'id': 1561619, 'text': '<p><span style="back...
# Name: questions, dtype: object

# %%
print(df['questions'].iloc[0])
# Out:
# [{'id': 1095950, 'text': '<p>You are working on a Django project for a company that specializes in real estate. You need to choose a field type for the company’s model for storing property information that allows users to enter a price in US dollars. However, the company also operates in other countries and wants to support other currencies.</p><p>&nbsp;</p><p><strong style="color: rgb(0, 0, 0);">Which of the following is the best approach for choosing this field?</strong></p>', 'intro_text': None, 'type': 'multiple-choice', 'shuffle': True, 'answers': [{'id': 9252450, 'text': '<p>Create a field that stores the price as a <code><strong>DecimalField</strong></code> and the currency code as a <code><strong>CharField</strong></code>.</p>', 'score': 5, 'rich_text': False}, {'id': 9252451, 'text': '<p>Create a <code><strong>DecimalField</strong></code> and allow users to enter the currency code as a separate field.</p>', 'score': 0, 'rich_text': False}, {'id': 9252452, 'text': "<p>Use Django's built-in <code><strong>MoneyField</strong></code> and add support for additional currencies.</p>", 'score': 0, 'rich_text': False}, {'id': 9252453, 'text': "<p>Employ Django's built-in <code><strong>CurrencyField</strong></code> and add support for US dollars.</p>", 'score': 0, 'rich_text': False}], 'skill_area': 1294804, 'status': 'active', 'state': 'new', 'order': 1, 'has_changed': False, 'has_versions': False, 'duration': 0, 'previous_version': None, 'identifier': 'Q00.001', 'code_language': None, 'initial_code': None, 'correct_code': 'not-applicable', 'return_type': 'str', 'function_name': None, 'code_params': [], 'code_test_cases': [], 'sql_return_type': 'SELECT', 'initial_sql': None, 'sql_test_cases': [], 'typing_test_type': None, 'typing_test_config': None, 'typing_test_mode': {'numbers': False, 'punctuation': False, 'funbox': 'none', 'sentences': False}, 'long_answer_list': False, 'max_items': 100, 'min_items': 0, 'scale': 5, 'custom_question_id': 1095950, 'what_to_look_for_in_the_answer': '', 'why_is_this_question_relevant': '', 'title': '', 'category': [], 'language': 'en', 'default_language': 'en', 'resources': [], 'boilerplates': [], 'programming_solutions': [], 'test_cases': [], 'test_version_number': 1}, {'id': 1095951, 'text': '<p>You have been hired as a Django website developer for an up-and-coming social media app company.&nbsp;You are working on the Django view responsible for displaying a list of posts from the social media app. You want to write a test to verify that the view uses the correct template. You’ve started with the code shown below.</p><p>&nbsp;</p><p><strong>Which line of code correctly completes the snippet to set up tests for this?</strong></p><p><strong>&nbsp;</strong></p><pre class="ql-syntax" spellcheck="false"><span class="hljs-keyword">from</span> django.test <span class="hljs-keyword">import</span> TestCase\n<span class="hljs-keyword">from</span> django.urls <span class="hljs-keyword">import</span> reverse\n<span class="hljs-class"><span class="hljs-keyword">class</span> <span class="hljs-title">PostsTestCase</span><span class="hljs-params">(TestCase)</span>:</span>\n&nbsp;&nbsp;&nbsp;<span class="hljs-function"><span class="hljs-keyword">def</span> <span class="hljs-title">test_post_template</span><span class="hljs-params">(self)</span>:</span>\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;url = reverse(<span class="hljs-string">\'posts\'</span>)\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;response = self.client.get(url)\n</pre>', 'intro_text': None, 'type': 'multiple-choice', 'shuffle': True, 'answers': [{'id': 9252454, 'text': "<p><code><strong>self.assertEqual(response.template, 'core/posts.html')</strong></code></p>", 'score': 0, 'rich_text': False}, {'id': 9252455, 'text': "<p><code><strong>self.assertTemplateUsed(response.template, 'core/posts.html')</strong></code></p>", 'score': 0, 'rich_text': False}, {'id': 9252456, 'text': "<p><code><strong>self.assertTemplateUsed(response, 'core/posts.html')</ ...

# %%
def clean_html(text):
    clean_text = a.sub(r'<.*?>', '', text) 
    clean_text = clean_text.replace('&nbsp;', ' ')
    return clean_text.strip()


distinct_question_types = {}

for question_list in df['questions']:
    for question in question_list:
        question_type = None
        correct_answers = []

        if question['type'] == 'multiple-choice':
            question_type = 2
            for answer in question['answers']:
                if answer['score'] >= 5:
                    correct_answers.append(clean_html(answer['text']))
        
        elif question['type'] == 'true-false':
            question_type = 11
            for answer in question['answers']:
                if answer['score'] >= 5:
                    correct_answers.append(clean_html(answer['text']))
        
        elif question['type'] == 'multiple-choice':
            question_type = 15
            for answer in question['answers']:
                if answer['score'] == 5:
                    correct_answers.append(clean_html(answer['text']))
                    
        if question_type not in [2, 11, 15]:
            continue
        
        distinct_question_types[question['id']] = {
            "ques_type": question_type,
            "correct_answers": correct_answers
        }

print(json.dumps(distinct_question_types, indent=2))
# Out:
# {
#   "1095950": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a field that stores the price as a DecimalField and the currency code as a CharField."
#     ]
#   },
#   "1095951": {
#     "ques_type": 2,
#     "correct_answers": [
#       "self.assertTemplateUsed(response, 'core/posts.html')"
#     ]
#   },
#   "1095952": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Define the form as a subclass of forms.ModelForm with name, email, subject, and message in the fields array."
#     ]
#   },
#   "1095953": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Apply the ```title``` HTML template filter, e.g., {{ value | title }}"
#     ]
#   },
#   "155197": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Combine the RUN commands separated by &amp;&amp;."
#     ]
#   },
#   "155200": {
#     "ques_type": 2,
#     "correct_answers": [
#       "echo $PASSWORD | docker login registry.company.com --username $USERNAME --password-stdin"
#     ]
#   },
#   "155206": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The registry will only store the first image pushed but will create two separate tags that point to the same layer."
#     ]
#   },
#   "615710": {
#     "ques_type": 2,
#     "correct_answers": [
#       "public class Book\n{\n           public virtual Author Author { get; set; }\n}\nvar books = db.Books.Include(b=&gt;b.Author).ToList();\nvar author = books[0].Author;"
#     ]
#   },
#   "615711": {
#     "ques_type": 2,
#     "correct_answers": [
#       "FromUri"
#     ]
#   },
#   "615713": {
#     "ques_type": 2,
#     "correct_answers": [
#       "private async Task BroadcastMarket()\n       {\n           await Hub.Clients.All.SendAsync(\"Price Change\");\n      }"
#     ]
#   },
#   "1561619": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GET"
#     ]
#   },
#   "1561621": {
#     "ques_type": 2,
#     "correct_answers": [
#       "/contacts/{contact_id}"
#     ]
#   },
#   "1561622": {
#     "ques_type": 2,
#     "correct_answers": [
#       "401 if the user doesn\u2019t exist or if the password is wrong."
#     ]
#   },
#   "1561624": {
#     "ques_type": 2,
#     "correct_answers": [
#       "{\n\u201cphone\u201d: \u201c123-123-1234\u201d\n}"
#     ]
#   },
#   "981988": {
#     "ques_type": 2,
#     "correct_answers": [
#       "afterupdate"
#     ]
#   },
#   "981989": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create the lookup relationship first"
#     ]
#   },
#   "981990": {
#     "ques_type": 2,
#     "correct_answers": [
#       "insert new Employeedatabase(EmpName = 'Alfred');\nEmployeedatabase acc = [SELECT Id FROM Employeedatabase WHERE EmpName = 'Alfred' LIMIT 1];\nString name = [SELECT Id, EmpName FROM Employeedatabase WHERE EmpName = 'Alfred' LIMIT 1].EmpName;"
#     ]
#   },
#   "981991": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The Decorator pattern and the Strategy pattern"
#     ]
#   },
#   "435324": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Alice should encrypt the document using Bob\u2019s public key and send it to Bob; Bob should decrypt it using his private key"
#     ]
#   },
#   "435325": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Give each employee a unique public/private key pair, encrypt the AES secret key using each employee's public key and email the encrypted key to them."
#     ]
#   },
#   "435328": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The document has not been tampered with"
#     ]
#   },
#   "370651": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Set"
#     ]
#   },
#   "370652": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A and C"
#     ]
#   },
#   "370653": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A and C"
#     ]
#   },
#   "1148738": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@app.get(\"book/{book_id:int}\")\nasync def get_by_id():\n  pass\n\n@app.get(\"book/{book_name:str}\")\nasync def get_by_name():\n  pass"
#     ]
#   },
#   "1148739": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@app.put(\"/item/{id}\")\nasync def inv(id:int, count: int = Query(...,le=10,gt=0)):\n\u00a0\u00a0pass"
#     ]
#   },
#   "1148741": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@app.get(\"/\")\ndef process_form(info: dict = Depends(ProcessKey())):\n  pass"
#     ]
#   },
#   "1148745": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@app.middleware(\"http\")\nasync def check(request:Request, call_next):\n  if request.url.path == '/old_warehouse' and request.client[0] in address_list:\n    return RedirectResponse(url=\"/new_warehouse\")\n  return await call_next(request)"
#     ]
#   },
#   "1529944": {
#     "ques_type": 2,
#     "correct_answers": [
#       "public/index.php"
#     ]
#   },
#   "1529946": {
#     "ques_type": 2,
#     "correct_answers": [
#       "auth.php"
#     ]
#   },
#   "1529947": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Traits cannot define the constructor method"
#     ]
#   },
#   "1428452": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Graph database"
#     ]
#   },
#   "1428453": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Optimize the query structure to reduce data scanning."
#     ]
#   },
#   "1428454": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement a denormalized schema with reference links to related data."
#     ]
#   },
#   "1428455": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Native support for horizontal scaling and data replication."
#     ]
#   },
#   "1056651": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use a salted hash algorithm to hash passwords securely."
#     ]
#   },
#   "1056653": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Review and update Firestore security rules for proper access restrictions on sensitive data."
#     ]
#   },
#   "1056656": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Enable Firebase Crashlytics to capture and report errors within the Cloud Function."
#     ]
#   },
#   "1056658": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Verify the accuracy of user topic subscriptions and device tokens."
#     ]
#   },
#   "1027529": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A microcontroller that supports multiple power modes with Bluetooth connectivity."
#     ]
#   },
#   "1027531": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GPIOs as input, pull down, sensing rising edge."
#     ]
#   },
#   "1027533": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Setting a breakpoint using a debugger."
#     ]
#   },
#   "1027536": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Set up a 20-millisecond timer interrupt. Call only ReadEcgSensor inside the interrupt service routine. Update the display less frequently using non-blocking APIs."
#     ]
#   },
#   "1561262": {
#     "ques_type": 2,
#     "correct_answers": [
#       "while not network.is_online(): sleep(1)"
#     ]
#   },
#   "1561264": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a single class to manage the file explorer."
#     ]
#   },
#   "823789": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a new extension in the Dynamics 365 Development Environment and add the new field to the Contact form using C# or JavaScript code."
#     ]
#   },
#   "823790": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a new entity in Dynamics 365 using the \"Customize Entities\" feature and use the \"Add Existing\" option to add the relationship to the \"Account\" entity."
#     ]
#   },
#   "823791": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a new custom web service using C# or JavaScript code and use the Dynamics 365 Web Services feature to secure the service."
#     ]
#   },
#   "823792": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a new extension in the Dynamics 365 Business Central Development Environment and add a new page using C/AL code, and include the necessary filters and sorting options using C/AL code."
#     ]
#   },
#   "393691": {
#     "ques_type": 2,
#     "correct_answers": [
#       "git init"
#     ]
#   },
#   "393692": {
#     "ques_type": 2,
#     "correct_answers": [
#       "git checkout -b new-branches"
#     ]
#   },
#   "107563": {
#     "ques_type": 2,
#     "correct_answers": [
#       "80, 50"
#     ]
#   },
#   "107566": {
#     "ques_type": 2,
#     "correct_answers": [
#       "32, +, 35, /, 4, - 44"
#     ]
#   },
#   "107569": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Array of n elements"
#     ]
#   },
#   "107572": {
#     "ques_type": 2,
#     "correct_answers": [
#       "An object of Employee class is created on heap."
#     ]
#   },
#   "1231355": {
#     "ques_type": 2,
#     "correct_answers": [
#       "about_page:\npath: /about\ncontroller: App\\Controller\\AboutController::index"
#     ]
#   },
#   "1231356": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@Id OR #[ORM\\Id] #[ORM\\Column]"
#     ]
#   },
#   "1231359": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a form class, instantiate it in the controller, and render it in the template using form_start() and form_end() in Twig."
#     ]
#   },
#   "1231361": {
#     "ques_type": 2,
#     "correct_answers": [
#       "buildForm()"
#     ]
#   },
#   "1322153": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create an IAM role with the proper permissions, and attach the role to the EC2 instance."
#     ]
#   },
#   "1322154": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Enable S3 event notifications to trigger a Lambda that will handle the logic."
#     ]
#   },
#   "1322155": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Migrate the database to AWS RDS."
#     ]
#   },
#   "1322157": {
#     "ques_type": 2,
#     "correct_answers": [
#       "AWS Glacier"
#     ]
#   },
#   "5675": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The code will fail, but changing the Contract model will make it work, as follows:employee = models.ForeignKey(Employee,  on_delete=models.CASCADE, related_name='contracts')"
#     ]
#   },
#   "5684": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The serializer"
#     ]
#   },
#   "409291": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create tt_users.links.task.yml and write the following code:tt_users.credit_score_tab:\n route_name: tt_users.credit_score\n base_route: entity.user.canonical\n title: 'Credit score'"
#     ]
#   },
#   "409292": {
#     "ques_type": 2,
#     "correct_answers": [
#       "function template_preprocess_entity_slider(&amp;$variables) {\n// Prepare variables.\n}"
#     ]
#   },
#   "409293": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a view of the research nodes as a block type, add a relationship to field_disease of the disease node, add a contextual filter, and add the block to the disease node."
#     ]
#   },
#   "409294": {
#     "ques_type": 2,
#     "correct_answers": [
#       "composer outdated drupal/*"
#     ]
#   },
#   "1086271": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Leverage Azure Monitor for APIs and select the metric \u201crequests.\u201d"
#     ]
#   },
#   "1086272": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Performance"
#     ]
#   },
#   "1086274": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Leverage Azure AKS, Azure\u2019s managed Kubernetes solution."
#     ]
#   },
#   "1086600": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Policy"
#     ]
#   },
#   "425457": {
#     "ques_type": 2,
#     "correct_answers": [
#       "word.length()"
#     ]
#   },
#   "425458": {
#     "ques_type": 2,
#     "correct_answers": [
#       "no-argument constructor"
#     ]
#   },
#   "425459": {
#     "ques_type": 2,
#     "correct_answers": [
#       "private int var1"
#     ]
#   },
#   "5348": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The degree of impact a defect has on the system."
#     ]
#   },
#   "5354": {
#     "ques_type": 2,
#     "correct_answers": [
#       "To validate that each unit of the software performs as designed."
#     ]
#   },
#   "1035294": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a namespace for each."
#     ]
#   },
#   "1035295": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Deployment"
#     ]
#   },
#   "1035296": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a StatefulSet + Headless Service."
#     ]
#   },
#   "1035297": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a ClusterRole and ClusterRoleBinding for the super admin and Role/RoleBinding for namespace-specific admins."
#     ]
#   },
#   "422685": {
#     "ques_type": 2,
#     "correct_answers": [
#       "{{ item | default('Available soon') }}"
#     ]
#   },
#   "422687": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@pytest.fixture"
#     ]
#   },
#   "422689": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement a user_loader callback using Flask-Login."
#     ]
#   },
#   "422696": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@app.route('/create-user/', methods=['POST'])"
#     ]
#   },
#   "1151704": {
#     "ques_type": 2,
#     "correct_answers": [
#       "heroku create forum-node-api"
#     ]
#   },
#   "1151708": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Set const port = 3000; in Node.js."
#     ]
#   },
#   "1151710": {
#     "ques_type": 2,
#     "correct_answers": [
#       "In the Activity tab in the Heroku Dashboard."
#     ]
#   },
#   "1151712": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Turn on multi-factor authentication."
#     ]
#   },
#   "463125": {
#     "ques_type": 2,
#     "correct_answers": [
#       "LateUpdate for camera; FixedUpdate for physics"
#     ]
#   },
#   "463126": {
#     "ques_type": 2,
#     "correct_answers": [
#       "It suspends the coroutine for four seconds."
#     ]
#   },
#   "463127": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the InitState(int seed); function."
#     ]
#   },
#   "332215": {
#     "ques_type": 2,
#     "correct_answers": [
#       "500"
#     ]
#   },
#   "332218": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GET /test?first=hello&amp;second=world"
#     ]
#   },
#   "332221": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The middleware returns a response with the Content-Type text/html."
#     ]
#   },
#   "65002": {
#     "ques_type": 2,
#     "correct_answers": [
#       "There is enough information to begin working on the software/UI design."
#     ]
#   },
#   "65003": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Encrypt data using symmetric encryption algorithms like AES."
#     ]
#   },
#   "65004": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use a blob store like Amazon S3/Google cloud platform to store the report and have a reference to the file in the database."
#     ]
#   },
#   "65005": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement the required APIs in the service and let the UI team access data through the APIs."
#     ]
#   },
#   "612954": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Rebroadcast the correct transaction amount with a higher gas fee."
#     ]
#   },
#   "612955": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Distributed decentralized ledger"
#     ]
#   },
#   "612956": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Eliminate loops by predetermined complex calculations and storing data in a data structure."
#     ]
#   },
#   "612957": {
#     "ques_type": 2,
#     "correct_answers": [
#       "ERC721a"
#     ]
#   },
#   "152503": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A service class is better represented by @Service to indicate that it holds business logic."
#     ]
#   },
#   "152515": {
#     "ques_type": 2,
#     "correct_answers": [
#       "If the @CrossOrigin annotation or the CORS configuration includes the website it\u2019s being called from."
#     ]
#   },
#   "523318": {
#     "ques_type": 2,
#     "correct_answers": [
#       "function withdraw(uint wdraw_amt) public {\nif (wdraw_amt &lt;= balance) {\nbalance -= wdraw_amt;\n} else {\nrevert(\"Insufficient Balance\");"
#     ]
#   },
#   "523321": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sketchs.push(_sketch);\nuint _id = sketchs.length - 1;"
#     ]
#   },
#   "523324": {
#     "ques_type": 2,
#     "correct_answers": [
#       "let message = await greeting.getGreeting.call();"
#     ]
#   },
#   "1660283": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Bundle the username into a key-value pair and pass it with an Intent."
#     ]
#   },
#   "1660284": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The app will display a blank screen."
#     ]
#   },
#   "1660286": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Image D"
#     ]
#   },
#   "1660287": {
#     "ques_type": 2,
#     "correct_answers": [
#       "@After"
#     ]
#   },
#   "9191": {
#     "ques_type": 2,
#     "correct_answers": [
#       "define('WP_MEMORY_LIMIT', '256M'); in wp-config.php"
#     ]
#   },
#   "9650": {
#     "ques_type": 2,
#     "correct_answers": [
#       "remove_action('wp_head', 'wp_generator');"
#     ]
#   },
#   "9800": {
#     "ques_type": 2,
#     "correct_answers": [
#       "&lt;?php plug_dir_path( $file ); ?&gt;"
#     ]
#   },
#   "52549": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Search before attribute in referenceContainer element in layout xml files and remove the 'before' attribute."
#     ]
#   },
#   "52550": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Copy the &lt;div data-bind=\"scope: 'messages'\"&gt; with its knockout block from messages.phtml and paste under product-addtocart-button element."
#     ]
#   },
#   "52551": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Write &lt;resource ref=\u201cMagento_CatalogInventory::cataloginventory\u201d/&gt; inside the &lt;resources&gt; tag."
#     ]
#   },
#   "531230": {
#     "ques_type": 2,
#     "correct_answers": [
#       "O(1)"
#     ]
#   },
#   "531231": {
#     "ques_type": 2,
#     "correct_answers": [
#       "2"
#     ]
#   },
#   "531232": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Pick the person with the lowest salary available from each of the departments."
#     ]
#   },
#   "531233": {
#     "ques_type": 2,
#     "correct_answers": [
#       "O(V+E)"
#     ]
#   },
#   "515936": {
#     "ques_type": 2,
#     "correct_answers": [
#       "After you are finished with each feature/task."
#     ]
#   },
#   "515937": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Fork the existing open-source project and make changes to it."
#     ]
#   },
#   "515938": {
#     "ques_type": 2,
#     "correct_answers": [
#       "index.html"
#     ]
#   },
#   "34117": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a Cloud Logging Logs-based metric with an alerting policy and push it to Pub/Sub subscription."
#     ]
#   },
#   "34088": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Install the GCP OS patch management agent on your GCP and on-premise servers and deploy the patches via patch jobs."
#     ]
#   },
#   "34541": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Private Zones"
#     ]
#   },
#   "34569": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Cloud Storage One Zone - Coldline Storage"
#     ]
#   },
#   "212197": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Author.joins(:books).distinct"
#     ]
#   },
#   "212200": {
#     "ques_type": 2,
#     "correct_answers": [
#       "(I) and (III) are similar, and (II) and (IV) are similar."
#     ]
#   },
#   "536853": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Define a custom enum that can contain either u32 or String, and make that the type of the vector."
#     ]
#   },
#   "536860": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create the response variable as a mutable string before the if {} block, so it is in the scope of the main() function."
#     ]
#   },
#   "536861": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Run the cargo new command with the --lib option."
#     ]
#   },
#   "573884": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use Node.js\u2019s global object instead."
#     ]
#   },
#   "573890": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the --save-dev flag when installing the package with npm install."
#     ]
#   },
#   "573893": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Express"
#     ]
#   },
#   "1571964": {
#     "ques_type": 2,
#     "correct_answers": [
#       "WebSockets"
#     ]
#   },
#   "1571966": {
#     "ques_type": 2,
#     "correct_answers": [
#       "enum Order {\n PIZZA\n SODA\n BREAD\n}"
#     ]
#   },
#   "1571967": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use Apollo Server's createError function to generate a GraphQL error object and return it to the client."
#     ]
#   },
#   "998760": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Install the supported version of Java."
#     ]
#   },
#   "998761": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Include the installation of the Kubernetes plugin in the Jenkins dockerfile."
#     ]
#   },
#   "998762": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the existing REPO_ACCESS_USR variable."
#     ]
#   },
#   "998763": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Fixed port for agent connections."
#     ]
#   },
#   "728150": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Apologize and check the system for a similar room to assign to the guest."
#     ]
#   },
#   "728151": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Explain to the guest that only loyalty program members qualify for an upgrade and offer to share program details."
#     ]
#   },
#   "728152": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Be empathetic, but tell her that using the computer for personal use can get her into trouble."
#     ]
#   },
#   "728153": {
#     "ques_type": 2,
#     "correct_answers": [
#       "You tell the leadership team about the rumors and discuss whether they should change the communication plan."
#     ]
#   },
#   "745767": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Click Test and then select the contact to test (C)."
#     ]
#   },
#   "745768": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Conversations &gt; Inbox &gt; Filter: Status = Open &gt; Channel = Live Chat"
#     ]
#   },
#   "745772": {
#     "ques_type": 2,
#     "correct_answers": [
#       "30 minutes"
#     ]
#   },
#   "45215": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Customer segment"
#     ]
#   },
#   "45303": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ask the customer what problems they are trying to solve with the feature to understand the pain point that will inform the best solution."
#     ]
#   },
#   "45277": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cHow are you currently solving the problem this feature would address?\u201d"
#     ]
#   },
#   "2061828": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cPress the big power button two times.\u201d"
#     ]
#   },
#   "2061829": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cI\u2019ve now frozen your account. I&#39;m sorry that you had this experience. Don&#39;t hesitate to call if you need any other help with your account.\u201d"
#     ]
#   },
#   "2061830": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cCould you check the delivery box to see if an extra power cable was included as a free gift?\u201d"
#     ]
#   },
#   "2063238": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Resolve the customer\u2019s delivery issue, then report the recurring complaints about Jo to your manager."
#     ]
#   },
#   "1017683": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Account &gt; Security &gt; Advanced &gt;  Account Assumption &gt; enable"
#     ]
#   },
#   "1017684": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Bulk edit the tickets to apply the same answers."
#     ]
#   },
#   "1017685": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Update the default trigger \u201cnotify user request received with \u201cday off // is // no\u201d."
#     ]
#   },
#   "1017686": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Generate a report on Explore."
#     ]
#   },
#   "370210": {
#     "ques_type": 2,
#     "correct_answers": [
#       "MAC filtering is enabled"
#     ]
#   },
#   "370212": {
#     "ques_type": 2,
#     "correct_answers": [
#       "It will use an APIPA IP address"
#     ]
#   },
#   "370213": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Understand the wireless network requirements"
#     ]
#   },
#   "370214": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SSH"
#     ]
#   },
#   "1210090": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a sharing rule for cross-role lead access."
#     ]
#   },
#   "1210091": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Review the communication history with these leads and identify any unresolved objections."
#     ]
#   },
#   "1210098": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Define a workflow rule with a \"Hot\" status trigger."
#     ]
#   },
#   "1210099": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a hierarchy of chart elements with clickable elements."
#     ]
#   },
#   "2067282": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cI understand your urgency. May I place you on a brief hold while I speak with my colleagues regarding this rush order?\u201d"
#     ]
#   },
#   "2067283": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Actively listen to the customer\u2019s concerns, and offer the customer a replacement item of clothing."
#     ]
#   },
#   "2067284": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Get back to the customer to thank them for their patience, elaborate on the reason for the delay and request more time."
#     ]
#   },
#   "706356": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\"What sort of trips do you take with your family?\""
#     ]
#   },
#   "706357": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cI understand you\u2019re looking for the best laptop. Let\u2019s look at a side-by-side comparison of both products so you can make an informed decision.\u201d"
#     ]
#   },
#   "706358": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Send them direct, personalized messages on important dates, such as their birthday and wedding anniversary."
#     ]
#   },
#   "728563": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Customer orientation"
#     ]
#   },
#   "728564": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ask the waiter to use service cloths or a tray to carry the item"
#     ]
#   },
#   "728565": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Give a basic call summary, ask if there is anything else you can help out with, and finish with a courtesy statement."
#     ]
#   },
#   "728566": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Handling raw meat and vegetables without washing hands in between."
#     ]
#   },
#   "1295196": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Step in and calmly address the customer's concerns."
#     ]
#   },
#   "1295197": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Analyze the customer feedback to pinpoint which styles, colors, or sizes of dresses are requested."
#     ]
#   },
#   "1295209": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Hold regular one-on-one meetings with each team member."
#     ]
#   },
#   "46016": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The customer\u2019s net promoter score (NPS) gets lower over time"
#     ]
#   },
#   "46017": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cIf this were happening to me, I would feel frustrated, too.\u201d"
#     ]
#   },
#   "46019": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Solving a pain point"
#     ]
#   },
#   "27049": {
#     "ques_type": 2,
#     "correct_answers": [
#       "As goodwill"
#     ]
#   },
#   "27050": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Precedent transactions: This shows how previous investors have assessed the risk of the uncertain cashflows."
#     ]
#   },
#   "27051": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Calculation tabs"
#     ]
#   },
#   "27052": {
#     "ques_type": 2,
#     "correct_answers": [
#       "To find inconsistencies or hard-coded inputs."
#     ]
#   },
#   "1155460": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Convert to a text-based field such as string or character."
#     ]
#   },
#   "1155472": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ask the manager who will be attending the conference what she aims to demonstrate in the write-up."
#     ]
#   },
#   "1155478": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A decrease in foot traffic in the area."
#     ]
#   },
#   "414102": {
#     "ques_type": 2,
#     "correct_answers": [
#       "It will produce an error."
#     ]
#   },
#   "414103": {
#     "ques_type": 2,
#     "correct_answers": [
#       "It will return an error."
#     ]
#   },
#   "414105": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GET animals/_search\n             {\n             \"query\": {\n             \"multi_match\": {\n            \"query\" : \" search_string \"\n            , \"fields\": [\"habitat\",\"food\"]\n             }\n             }\n             }"
#     ]
#   },
#   "414106": {
#     "ques_type": 2,
#     "correct_answers": [
#       "console.ui.enabled: false"
#     ]
#   },
#   "1562899": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Send email surveys to customers across different store locations, demographics, and purchase histories."
#     ]
#   },
#   "1562900": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Procure all components from Supplier A."
#     ]
#   },
#   "1562902": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use linear regression to model sales trends."
#     ]
#   },
#   "1562903": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Optimize inventory levels."
#     ]
#   },
#   "372099": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Perform a one-hot encoding for any two colors."
#     ]
#   },
#   "372100": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Pie chart"
#     ]
#   },
#   "372101": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A multivariate regression analysis and drop if the p value is greater than 0.05 (Given that \u0251 = 0.05)."
#     ]
#   },
#   "1133799": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Data Factory"
#     ]
#   },
#   "1133804": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Databricks"
#     ]
#   },
#   "1133812": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Utilize Power Query to extract and transform data into visual models."
#     ]
#   },
#   "1133821": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement Automatic Tuning to continuously adapt to changing workloads."
#     ]
#   },
#   "495649": {
#     "ques_type": 2,
#     "correct_answers": [
#       "1/3"
#     ]
#   },
#   "495651": {
#     "ques_type": 2,
#     "correct_answers": [
#       "0.0041"
#     ]
#   },
#   "495652": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Stratified sampling"
#     ]
#   },
#   "373003": {
#     "ques_type": 2,
#     "correct_answers": [
#       "numpy.zeros([3, 4])"
#     ]
#   },
#   "373004": {
#     "ques_type": 2,
#     "correct_answers": [
#       "arr *= 2"
#     ]
#   },
#   "373005": {
#     "ques_type": 2,
#     "correct_answers": [
#       "arr = numpy.nan_to_num(arr)"
#     ]
#   },
#   "1391434": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement a deep convolutional neural network (CNN) with residual connections."
#     ]
#   },
#   "1391444": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Adam optimizer"
#     ]
#   },
#   "1391455": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Convolutional neural network (CNN) with data augmentation"
#     ]
#   },
#   "1391456": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Transformer-based models"
#     ]
#   },
#   "844928": {
#     "ques_type": 2,
#     "correct_answers": [
#       "c(a, b)"
#     ]
#   },
#   "844930": {
#     "ques_type": 2,
#     "correct_answers": [
#       "levels"
#     ]
#   },
#   "844943": {
#     "ques_type": 2,
#     "correct_answers": [
#       "aes"
#     ]
#   },
#   "754286": {
#     "ques_type": 2,
#     "correct_answers": [
#       "LinearRegression(fit_intercept=False)"
#     ]
#   },
#   "754287": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SVR(gamma=\u201dauto\u201d)"
#     ]
#   },
#   "754298": {
#     "ques_type": 2,
#     "correct_answers": [
#       "(4, 8)"
#     ]
#   },
#   "718293": {
#     "ques_type": 2,
#     "correct_answers": [
#       "a/(b+c^2)+c/d*e/f"
#     ]
#   },
#   "718294": {
#     "ques_type": 2,
#     "correct_answers": [
#       "2"
#     ]
#   },
#   "718296": {
#     "ques_type": 2,
#     "correct_answers": [
#       "plot(age,weight)"
#     ]
#   },
#   "1100559": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use Amazon Kinesis Data Streams to ingest data in real-time and Amazon Simple Storage Service (S3) for storing different data formats."
#     ]
#   },
#   "1100560": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use AWS Glue for data cleaning and Amazon Simple Storage Service (S3) Select for data enrichment."
#     ]
#   },
#   "1100562": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Run SQL-like queries directly on the data using a suitable AWS service."
#     ]
#   },
#   "1100564": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create multi-column indexes covering the queried fields."
#     ]
#   },
#   "1078755": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use one GA4 property and configure it to track all subdomains together."
#     ]
#   },
#   "1078756": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Focus on each channel\u2019s impression count."
#     ]
#   },
#   "1078757": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use third-party connectors to import Meta Ads and LinkedIn Ads data into GA4."
#     ]
#   },
#   "1078758": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Generate a bar chart in GA4 comparing sales revenue for different product categories."
#     ]
#   },
#   "442504": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Both primary key and foreign key"
#     ]
#   },
#   "442505": {
#     "ques_type": 2,
#     "correct_answers": [
#       "OR"
#     ]
#   },
#   "442506": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Aggregate functions"
#     ]
#   },
#   "464370": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The survey should be applied to all participating students, including feedback from the coordinators."
#     ]
#   },
#   "464373": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Option C"
#     ]
#   },
#   "464374": {
#     "ques_type": 2,
#     "correct_answers": [
#       "What do you like most about cleaning your kitchen?"
#     ]
#   },
#   "823561": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Walk the staff through the process they use to get the data."
#     ]
#   },
#   "823562": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Engage with the chief actuary and staff to understand the rating process."
#     ]
#   },
#   "823565": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Query the actuarial staff on the tasks they perform for rate making and the data fields they use in each task."
#     ]
#   },
#   "658843": {
#     "ques_type": 2,
#     "correct_answers": [
#       "ETF B"
#     ]
#   },
#   "658844": {
#     "ques_type": 2,
#     "correct_answers": [
#       "$1,500"
#     ]
#   },
#   "658845": {
#     "ques_type": 2,
#     "correct_answers": [
#       "ETF that exclusively holds real estate investments trusts (REITs)."
#     ]
#   },
#   "658846": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Enter a swap agreement to pay the return on $500,000 worth of AMZN shares and receive the return on a Treasury bond index for six months."
#     ]
#   },
#   "818526": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Shopping behavior: consumers\u2019 path on the website and inside the cart"
#     ]
#   },
#   "818527": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Organic search traffic to the website"
#     ]
#   },
#   "818528": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The core audience is under 25 years old."
#     ]
#   },
#   "1299561": {
#     "ques_type": 2,
#     "correct_answers": [
#       "=TEXTJOIN(\",\", TRUE, A2, B2, C2)"
#     ]
#   },
#   "1299567": {
#     "ques_type": 2,
#     "correct_answers": [
#       "=IFERROR(formula, \"Data Error\")"
#     ]
#   },
#   "1299568": {
#     "ques_type": 2,
#     "correct_answers": [
#       "=PROPER(column_name)"
#     ]
#   },
#   "1299570": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Check to see if the lookup value (A2) contains leading or trailing spaces."
#     ]
#   },
#   "625251": {
#     "ques_type": 2,
#     "correct_answers": [
#       "For a continuous distribution, any particular event has probability 0 to occur."
#     ]
#   },
#   "625252": {
#     "ques_type": 2,
#     "correct_answers": [
#       "36/54"
#     ]
#   },
#   "625254": {
#     "ques_type": 2,
#     "correct_answers": [
#       "CNNs are well suited to high dimensional data, which results in them needing to learn fewer parameters."
#     ]
#   },
#   "1643357": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Two-tier"
#     ]
#   },
#   "1643358": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Simplify or optimize the transformation logic."
#     ]
#   },
#   "1643359": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Profile the transformation operations."
#     ]
#   },
#   "1643360": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement a checkpoint mechanism."
#     ]
#   },
#   "572537": {
#     "ques_type": 2,
#     "correct_answers": [
#       "gaming-stars-bot-cloudantNoSQLDB and gaming-stars-bot-cloudantNoSQLDB"
#     ]
#   },
#   "572539": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add a context variable so the existing assistant knows which product is currently discussed."
#     ]
#   },
#   "572540": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A search engine that finds products based on similar images."
#     ]
#   },
#   "572543": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create an entity @employee and a dialog node with a story for each employee."
#     ]
#   },
#   "1196794": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Dataflow"
#     ]
#   },
#   "1196795": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Dataprep"
#     ]
#   },
#   "1196796": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Utilize Looker Studio to create interactive dashboards and reports."
#     ]
#   },
#   "1196797": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Cloud Spanner"
#     ]
#   },
#   "476168": {
#     "ques_type": 2,
#     "correct_answers": [
#       "1.8%"
#     ]
#   },
#   "476169": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The client should consider acquiring one or more existing companies with established infrastructure and presence in the market."
#     ]
#   },
#   "476170": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The unit price (price per gallon/liter) is expected to grow in the period between 2022-2026."
#     ]
#   },
#   "991068": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SparkSession.builder.config(\"key\", \"val\").getOrCreate()"
#     ]
#   },
#   "991070": {
#     "ques_type": 2,
#     "correct_answers": [
#       "0"
#     ]
#   },
#   "991071": {
#     "ques_type": 2,
#     "correct_answers": [
#       "setMaster"
#     ]
#   },
#   "1017244": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Map"
#     ]
#   },
#   "1017245": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Imputation with previous or next timestamp value"
#     ]
#   },
#   "1017249": {
#     "ques_type": 2,
#     "correct_answers": [
#       "100"
#     ]
#   },
#   "1654720": {
#     "ques_type": 2,
#     "correct_answers": [
#       "193"
#     ]
#   },
#   "1654721": {
#     "ques_type": 2,
#     "correct_answers": [
#       "2.5 days"
#     ]
#   },
#   "1654722": {
#     "ques_type": 2,
#     "correct_answers": [
#       "$20.00"
#     ]
#   },
#   "1654723": {
#     "ques_type": 2,
#     "correct_answers": [
#       "50%"
#     ]
#   },
#   "958287": {
#     "ques_type": 2,
#     "correct_answers": [
#       "18-34 years old"
#     ]
#   },
#   "958288": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Metadata"
#     ]
#   },
#   "958289": {
#     "ques_type": 2,
#     "correct_answers": [
#       "February to March"
#     ]
#   },
#   "958291": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Referral links"
#     ]
#   },
#   "1467670": {
#     "ques_type": 2,
#     "correct_answers": [
#       "To present the user flow."
#     ]
#   },
#   "1467676": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Continuously throughout the life cycle"
#     ]
#   },
#   "1467677": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The system\u2019s performance in relation to the business goals."
#     ]
#   },
#   "1411689": {
#     "ques_type": 2,
#     "correct_answers": [
#       "1. Authenticate the user.2. Validate the comment text.3. Insert the comment into the database."
#     ]
#   },
#   "1411690": {
#     "ques_type": 2,
#     "correct_answers": [
#       "(x,2)(y,4)(z,2)(x,4)"
#     ]
#   },
#   "1411691": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Determine which neighborhood each delivery address is in. Cluster the list by deliveries in the same neighborhood. Drive to each neighborhood once and deliver all of the packages in that neighborhood."
#     ]
#   },
#   "1411692": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Generalizing the common attributes and behaviors of different types of library items."
#     ]
#   },
#   "395097": {
#     "ques_type": 2,
#     "correct_answers": [
#       "fmt"
#     ]
#   },
#   "395099": {
#     "ques_type": 2,
#     "correct_answers": [
#       "log"
#     ]
#   },
#   "395100": {
#     "ques_type": 2,
#     "correct_answers": [
#       "edgecolors"
#     ]
#   },
#   "1711007": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Date of Birth"
#     ]
#   },
#   "1711008": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Calculate the sum of the numbers and divide by the amount of numbers in the set."
#     ]
#   },
#   "1711009": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Bar chart"
#     ]
#   },
#   "402951": {
#     "ques_type": 2,
#     "correct_answers": [
#       "ALTER TABLE Author ADD CONSTRAINT ck_age CHECK(AuthorAge &gt;= 10);"
#     ]
#   },
#   "402953": {
#     "ques_type": 2,
#     "correct_answers": [
#       "DELETE FROM Author WHERE AuthorID NOT IN (SELECT AuthorID FROM Book )"
#     ]
#   },
#   "402955": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GET DIAGNOSTICS CONDITION 1 @text = MESSAGE_TEXT;"
#     ]
#   },
#   "2070940": {
#     "ques_type": 2,
#     "correct_answers": [
#       "6"
#     ]
#   },
#   "2070943": {
#     "ques_type": 2,
#     "correct_answers": [
#       "3"
#     ]
#   },
#   "386949": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Adjust the values of SHMMAX and SHMALL in the sysctl.conf file and run sysctl with -p parameter to load in sysctl settings."
#     ]
#   },
#   "386950": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The location of the data files needs to be updated in the control file."
#     ]
#   },
#   "386953": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Backups before October 25"
#     ]
#   },
#   "386954": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Alter the database user with the Unlock User command."
#     ]
#   },
#   "561268": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Dim firstvariable as String"
#     ]
#   },
#   "561269": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Make the value of cell A4 equal to 5."
#     ]
#   },
#   "1187753": {
#     "ques_type": 2,
#     "correct_answers": [
#       "As an integer field in the customer record"
#     ]
#   },
#   "1187754": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SELECT DISTINCT address_state FROM customers;"
#     ]
#   },
#   "1187755": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use a Combo Box control with a value list from another table."
#     ]
#   },
#   "1187756": {
#     "ques_type": 2,
#     "correct_answers": [
#       "In a Group Footer section"
#     ]
#   },
#   "568401": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add a node."
#     ]
#   },
#   "568402": {
#     "ques_type": 2,
#     "correct_answers": [
#       "WHERE SeqNum &gt;1"
#     ]
#   },
#   "568404": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Restore the most recent full backup."
#     ]
#   },
#   "528914": {
#     "ques_type": 2,
#     "correct_answers": [
#       "create user gorilla with encrypted password 'P@$$word' LOGIN;"
#     ]
#   },
#   "528915": {
#     "ques_type": 2,
#     "correct_answers": [
#       "postgres -D /usr/local/pgsql/companydata &gt;logfile 2&gt;&amp;1 &amp;"
#     ]
#   },
#   "528918": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Append the pg_hba.conf file with:host  replication   all  192.168.10.2/32"
#     ]
#   },
#   "528919": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SELECT pid, wait_event_type, wait_event FROM pg_stat_activity WHERE wait_event is NOT NULL;"
#     ]
#   },
#   "78729": {
#     "ques_type": 2,
#     "correct_answers": [
#       "MongoDB mongos"
#     ]
#   },
#   "78731": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Enable access control and create database users with certain roles."
#     ]
#   },
#   "78735": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Check ulimit settings in the operating system and modify if necessary."
#     ]
#   },
#   "975905": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Purchase a third-party SSL certificate and install it on the SharePoint server."
#     ]
#   },
#   "975906": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Claims-based Authentication in the web application's Authentication Providers settings."
#     ]
#   },
#   "975907": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Configure a SharePoint farm with two servers, and use SQL Server Always On Availability Groups."
#     ]
#   },
#   "975909": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Configure SharePoint to use a dedicated server for search."
#     ]
#   },
#   "1482848": {
#     "ques_type": 2,
#     "correct_answers": [
#       "INFO MEMORY"
#     ]
#   },
#   "1482850": {
#     "ques_type": 2,
#     "correct_answers": [
#       "requirepass"
#     ]
#   },
#   "1482858": {
#     "ques_type": 2,
#     "correct_answers": [
#       "GRAPH.QUERY myGraph \"CREATE (n:Person {name: 'John', age: 30})\""
#     ]
#   },
#   "1482867": {
#     "ques_type": 2,
#     "correct_answers": [
#       "EVALSHA [ ...]"
#     ]
#   },
#   "1128843": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Star schema"
#     ]
#   },
#   "1128844": {
#     "ques_type": 2,
#     "correct_answers": [
#       "SELECT customer_id, SUM(transaction_amount) AS total_amount\nFROM transactions\nGROUP BY customer_id\nORDER BY total_amount DESC\nLIMIT 5;"
#     ]
#   },
#   "1128847": {
#     "ques_type": 2,
#     "correct_answers": [
#       "CREATE FILE FORMAT CSV_FORMAT\nTYPE = 'CSV'\nFIELD_DELIMITER = ','\nSKIP_HEADER = 1;"
#     ]
#   },
#   "1128864": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Switch to a medium warehouse."
#     ]
#   },
#   "599459": {
#     "ques_type": 2,
#     "correct_answers": [
#       "R1(A, B) and R2(B, C) and R3(C, D)"
#     ]
#   },
#   "599460": {
#     "ques_type": 2,
#     "correct_answers": [
#       "3"
#     ]
#   },
#   "599461": {
#     "ques_type": 2,
#     "correct_answers": [
#       "0"
#     ]
#   },
#   "412376": {
#     "ques_type": 2,
#     "correct_answers": [
#       "xhr.status"
#     ]
#   },
#   "412380": {
#     "ques_type": 2,
#     "correct_answers": [
#       "const container = document.querySelector(\".container\");\ndata.data.forEach((elm)=&gt;{\n     container.innerHTML += \"&lt;div&gt;\"+elm+\"&lt;/div&gt;\";\n });"
#     ]
#   },
#   "43249": {
#     "ques_type": 2,
#     "correct_answers": [
#       "They're to be launched before component's hooks."
#     ]
#   },
#   "43250": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Yes, if it does not return a function, otherwise no"
#     ]
#   },
#   "43251": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A client-side process during which Vue takes over the static HTML sent by the server and turns it into dynamic DOM that can react to client-side data changes."
#     ]
#   },
#   "43252": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Mustache interpolations and 'v-bind' expressions"
#     ]
#   },
#   "1077969": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use an {#each} block."
#     ]
#   },
#   "1077970": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Access the resolved promise data using an await block."
#     ]
#   },
#   "1077971": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add the once modifier."
#     ]
#   },
#   "1077972": {
#     "ques_type": 2,
#     "correct_answers": [
#       "+server.ts"
#     ]
#   },
#   "1051308": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use meaningful, built-in HTML tags like &lt;form&gt;, &lt;input&gt;, and &lt;button&gt;."
#     ]
#   },
#   "1051310": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Specify the language with the lang attribute to the top-level &lt;html&gt; tag."
#     ]
#   },
#   "1051311": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add the role=\u201dalert\u201d attribute."
#     ]
#   },
#   "1720803": {
#     "ques_type": 2,
#     "correct_answers": [
#       "npx next dev --hostname 192.168.1.2"
#     ]
#   },
#   "1720805": {
#     "ques_type": 2,
# ...
#   },
#   "1028310": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Customer acknowledgement"
#     ]
#   },
#   "955396": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Run a conflict check to determine if Mr. Smith is from the same Smith family."
#     ]
#   },
#   "955397": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Inform the client that billable hours include more than time spent in court."
#     ]
#   },
#   "955398": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Don\u2019t add them to the calendar unless the client also requests a meeting."
#     ]
#   },
#   "1116641": {
#     "ques_type": 2,
#     "correct_answers": [
#       "They should follow state law only if it is more stringent than HIPAA in protecting patient privacy."
#     ]
#   },
#   "1116642": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Acknowledgment of receipt of noticeConfidentiality statementAuthorization for use or disclosure of information"
#     ]
#   },
#   "1116643": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A penalty of up to $250,000 and up to 10 years in prison due to illegal sharing of protected health information for commercial purposes."
#     ]
#   },
#   "1116644": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Med record number, account number, health plan beneficiary number, dates directly related to an individual (like birth date, admission date, etc.)"
#     ]
#   },
#   "1504936": {
#     "ques_type": 2,
#     "correct_answers": [
#       "50"
#     ]
#   },
#   "1504937": {
#     "ques_type": 2,
#     "correct_answers": [
#       "12"
#     ]
#   },
#   "1504938": {
#     "ques_type": 2,
#     "correct_answers": [
#       "5"
#     ]
#   },
#   "1505111": {
#     "ques_type": 2,
#     "correct_answers": [
#       "B"
#     ]
#   },
#   "1565277": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Begin the interview by discussing shared interests, then gradually transition into the main topic."
#     ]
#   },
#   "1565278": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Prepare a list of questions that encourages the SME to explain concepts in layperson\u2019s terms and refocus them if they become too technical."
#     ]
#   },
#   "1565280": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use them to confirm details and extract concise responses on specific topics."
#     ]
#   },
#   "1565281": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Mirror the candidate's communication style while maintaining your professionalism."
#     ]
#   },
#   "1302661": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Military veterans job fair"
#     ]
#   },
#   "1302664": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Infection control procedures"
#     ]
#   },
#   "584970": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Return on investment."
#     ]
#   },
#   "584975": {
#     "ques_type": 2,
#     "correct_answers": [
#       "\u201cWould you like to role-play the conversation with me in advance and look at some talking points you can use?\u201d"
#     ]
#   },
#   "584977": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Determine if there is a position available within the company that can accommodate the lifting restriction."
#     ]
#   },
#   "1150318": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Conduct individual interviews with the new employees, observe them in their new roles, and gather supervisor feedback."
#     ]
#   },
#   "1150319": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Incorporate a variety of instructional methods into the program."
#     ]
#   },
#   "1150320": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ask for immediate feedback from participants after the training."
#     ]
#   },
#   "1150321": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Conduct a performance review to identify each team lead\u2019s strengths and areas for improvement."
#     ]
#   },
#   "1428064": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Increase sales of foam mattresses by 10%."
#     ]
#   },
#   "1428065": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ask for behavioral examples of dependability to integrate into a behavioral appraisal."
#     ]
#   },
#   "1428066": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Privately explain the performance issues and ask them to start documenting their fact-checking procedures."
#     ]
#   },
#   "1428067": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Maintain a log of each employee\u2019s key contributions and performance, updating it throughout each quarter."
#     ]
#   },
#   "886513": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Schedule a meeting with Sarah, and ask her to share her opinions and hesitancy regarding the new tasks."
#     ]
#   },
#   "886514": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Reply publicly: \u201cWe\u2019re sorry to hear about your bad experience and would like to hear more. Please reach out to me directly by email.\u201d"
#     ]
#   },
#   "886515": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Cook the chicken wings from frozen until the meat reaches an internal temperature of 165\u00b0F / 74\u00b0C."
#     ]
#   },
#   "2097586": {
#     "ques_type": 2,
#     "correct_answers": [
#       "dig"
#     ]
#   },
#   "2097588": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The use of cloud availability zones."
#     ]
#   },
#   "2097589": {
#     "ques_type": 2,
#     "correct_answers": [
#       "git checkout -b feature/testgorilla"
#     ]
#   },
#   "1243877": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Business Starter"
#     ]
#   },
#   "1243878": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Change it into a collaborative inbox."
#     ]
#   },
#   "1243883": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Methods &gt; Only Security Key"
#     ]
#   },
#   "2005447": {
#     "ques_type": 2,
#     "correct_answers": [
#       "alias ls"
#     ]
#   },
#   "2005448": {
#     "ques_type": 2,
#     "correct_answers": [
#       "w"
#     ]
#   },
#   "2005449": {
#     "ques_type": 2,
#     "correct_answers": [
#       "2"
#     ]
#   },
#   "2005554": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use an export statement."
#     ]
#   },
#   "433197": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Linked Value Replication"
#     ]
#   },
#   "433198": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Global"
#     ]
#   },
#   "433204": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Change logon hours."
#     ]
#   },
#   "433208": {
#     "ques_type": 2,
#     "correct_answers": [
#       "mkdir newadmins_bakbackup-gpo -name NewAdmins -path c:\\newadmins_bak\\"
#     ]
#   },
#   "476516": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Reset the computer account, then disjoin and rejoin the computer to the domain."
#     ]
#   },
#   "476517": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Security log"
#     ]
#   },
#   "476518": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement single sign-on capabilities by creating a trust relationship between these partner organizations and your extranet."
#     ]
#   },
#   "361021": {
#     "ques_type": 2,
#     "correct_answers": [
#       "terraform taint \"aws_instace.question[1]\"terraform apply"
#     ]
#   },
#   "361022": {
#     "ques_type": 2,
#     "correct_answers": [
#       "By including multiple provider blocks with the same provider name."
#     ]
#   },
#   "361023": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Create a security policy using Sentinel policies."
#     ]
#   },
#   "393011": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Get-Service | where {$_.Status -eq \"Running\"} | ConvertTo-Json"
#     ]
#   },
#   "393012": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Get-Command *NetAdapter*"
#     ]
#   },
#   "393013": {
#     "ques_type": 2,
#     "correct_answers": [
#       "$var = Get-AutomationVariable -Name 'newvar'"
#     ]
#   },
#   "393014": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Invoke-WebRequest"
#     ]
#   },
#   "380098": {
#     "ques_type": 2,
#     "correct_answers": [
#       "VMware vSphere Update Manager"
#     ]
#   },
#   "380099": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Check for VM locks to the virtual machine disk (VMDK) file and resolve it first."
#     ]
#   },
#   "380105": {
#     "ques_type": 2,
#     "correct_answers": [
#       "/var/log/vmware/hostd.log"
#     ]
#   },
#   "1310772": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Virtual WAN &amp; Azure ExpressRoute"
#     ]
#   },
#   "1310774": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Firewall &amp; Azure Security Center"
#     ]
#   },
#   "1310775": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure Network Watcher"
#     ]
#   },
#   "1310776": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Azure ExpressRoute"
#     ]
#   },
#   "29235": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the on-screen keyboard."
#     ]
#   },
#   "29236": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add --insecure to the curl request."
#     ]
#   },
#   "29237": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Private cloud"
#     ]
#   },
#   "29238": {
#     "ques_type": 2,
#     "correct_answers": [
#       "10.10.0.4"
#     ]
#   },
#   "2013179": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Help their developers implement password salting."
#     ]
#   },
#   "2013180": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Check whether cookies are HTTP-only to see if you can hijack sessions."
#     ]
#   },
#   "2013181": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add it as an install script in package.json."
#     ]
#   },
#   "656005": {
#     "ques_type": 2,
#     "correct_answers": [
#       "New-TransportRule"
#     ]
#   },
#   "656006": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Restore-Mailbox -Identity Alain -RecoveryDatabase Ex001"
#     ]
#   },
#   "656007": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Reduce the maximum size of email attachments to 25 MB."
#     ]
#   },
#   "437787": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Teams Apps &gt; Setup Policies"
#     ]
#   },
#   "437788": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Delta sync"
#     ]
#   },
#   "437789": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Run a PowerShell script to recover deleted files from Jason\u2019s account."
#     ]
#   },
#   "437790": {
#     "ques_type": 2,
#     "correct_answers": [
#       "eDiscovery administrator"
#     ]
#   },
#   "631173": {
#     "ques_type": 2,
#     "correct_answers": [
#       "[Row(Course='Spark', Rank=1)]"
#     ]
#   },
#   "631174": {
#     "ques_type": 2,
#     "correct_answers": [
#       "df1.unionByName(df2, allowMissingColumns=True).show()"
#     ]
#   },
#   "631175": {
#     "ques_type": 2,
#     "correct_answers": [
#       "[(1, 2)]"
#     ]
#   },
#   "892317": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Help Desk Operator"
#     ]
#   },
#   "892329": {
#     "ques_type": 2,
#     "correct_answers": [
#       "C"
#     ]
#   },
#   "892330": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The retirement of noncompliant devices."
#     ]
#   },
#   "25910": {
#     "ques_type": 2,
#     "correct_answers": [
#       "www.url.com/wp-admin"
#     ]
#   },
#   "25912": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Quote"
#     ]
#   },
#   "1330403": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Utilize Google Cloud Virtual Private Cloud (VPC) to create separate virtual networks for each application tier."
#     ]
#   },
#   "1330404": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Configure GCP's hierarchical firewall policies combined with Cloud Armor for geographical egress controls and integrate with a managed IDS/IPS service."
#     ]
#   },
#   "1330405": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Combine Google Cloud Network Intelligence Center with Cloud Monitoring and Logging, utilizing advanced metrics and log analysis for anomaly detection."
#     ]
#   },
#   "1330406": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Implement a hybrid topology using Google Cloud Interconnect and AWS Direct Connect, along with Traffic Director for dynamic traffic control."
#     ]
#   },
#   "1208492": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Local area network (LAN)"
#     ]
#   },
#   "1208493": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Ethernet wired network"
#     ]
#   },
#   "1208494": {
#     "ques_type": 2,
#     "correct_answers": [
#       "A failure in a connection-oriented (stateful) protocol"
#     ]
#   },
#   "1208495": {
#     "ques_type": 2,
#     "correct_answers": [
#       "It protects data confidentiality, integrity, and authenticity."
#     ]
#   },
#   "1053783": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sudo apt install -y nginx"
#     ]
#   },
#   "1053784": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sudo systemctl status nginx"
#     ]
#   },
#   "1053785": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sudo nano /etc/nginx/nginx.conf And add a directive:include /etc/mysites/*.conf;"
#     ]
#   },
#   "1313947": {
#     "ques_type": 2,
#     "correct_answers": [
#       "UDP (User Datagram Protocol)"
#     ]
#   },
#   "1313948": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Considering bandwidth requirements and choosing suitable network equipment."
#     ]
#   },
#   "1313949": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Capture and scrutinize the packet data associated with the file transfer for investigation."
#     ]
#   },
#   "1313950": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Review the Simple Network Management Protocol (SNMP) data from the switch."
#     ]
#   },
#   "1029917": {
#     "ques_type": 2,
#     "correct_answers": [
#       "OR"
#     ]
#   },
#   "1029918": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Binary"
#     ]
#   },
#   "1029921": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Resistors"
#     ]
#   },
#   "1029922": {
#     "ques_type": 2,
#     "correct_answers": [
#       "BIOS"
#     ]
#   },
#   "1104802": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Apply a client script to validate the \"Credit Limit\" field and display an error message if it is empty when \"Payment Terms\" is \"Net 60.\""
#     ]
#   },
#   "1104804": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the NetSuite Data Import Assistant to identify and merge duplicate customer records during the import process."
#     ]
#   },
#   "1104805": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Modify the saved search criteria to include the updated department codes and ensure data consistency."
#     ]
#   },
#   "1104806": {
#     "ques_type": 2,
#     "correct_answers": [
#       "The credit card type is not supported by NetSuite's payment gateway integration."
#     ]
#   },
#   "1252474": {
#     "ques_type": 2,
#     "correct_answers": [
#       "AWS Transit Gateway and VPC endpoints"
#     ]
#   },
#   "1252475": {
#     "ques_type": 2,
#     "correct_answers": [
#       "AWS WAF and Amazon CloudFront"
#     ]
#   },
#   "1252476": {
#     "ques_type": 2,
#     "correct_answers": [
#       "VPC Flow Logs"
#     ]
#   },
#   "1252477": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Amazon CloudFront"
#     ]
#   },
#   "648969": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Use the dig command."
#     ]
#   },
#   "648970": {
#     "ques_type": 2,
#     "correct_answers": [
#       "C"
#     ]
#   },
#   "648971": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Write the script as a Bourne Shell script (/bin/sh)."
#     ]
#   },
#   "782003": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sudo dpkg-reconfigure wireshark-common"
#     ]
#   },
#   "782004": {
#     "ques_type": 2,
#     "correct_answers": [
#       "tcp.analysis.flags"
#     ]
#   },
#   "782005": {
#     "ques_type": 2,
#     "correct_answers": [
#       "http.host==testgorilla.com"
#     ]
#   },
#   "782007": {
#     "ques_type": 2,
#     "correct_answers": [
#       "sip.response-time"
#     ]
#   },
#   "365120": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Dynamic inventory"
#     ]
#   },
#   "365122": {
#     "ques_type": 2,
#     "correct_answers": [
#       "Add a webserver restart notify handler call for each task that updates any configuration file."
#     ]
#   },
#   "365124": {
#     "ques_type": 2,
#     "correct_answers": [
#       "ansible-playbook update_config.yml --diff --check"
#     ]
#   }
# }

# %%
# df["questions"] = df["questions"].apply(lambda x: x if isinstance(x, list) else [])
# question_types = (
#     df["questions"]
#     .explode()
#     .dropna()
#     .apply(lambda q: q.get("type") if isinstance(q, dict) else None)
#     .dropna()
#     .unique()
# )
# print("Distinct question types:", question_types)

# %%
# def filter_questions(questions):
#     """Filter questions and assign appropriate ques_type."""
#     valid_types = {
#         "multiple-choice": 2,  # MCQ (Single correct)
#         "true-false": 11,      # True/False
#         "multiple-select": 15  # MCQ (Multiple correct)
#     }

#     cleaned_questions = []
    
#     for q in questions:
#         if not isinstance(q, dict):
#             continue  # Skip invalid entries
        
#         q_type = q.get("type", None)
#         ques_type = valid_types.get(q_type, None)  # Get ques_type or None
        
#         if ques_type is not None:
#             cleaned_question = {
#                 "id": q.get("id", None),
#                 "text": clean_html(q.get("text", "")),  # Clean HTML
#                 "ques_type": ques_type,
#                 "answers": q.get("answers", [])
#             }
#             cleaned_questions.append(cleaned_question)
    
#     return cleaned_questions
# df.head()
